# %%
import folium
import pandas as pd
import pandas

# %% [markdown]
# # Additional Layers
#
#
# In this notebook, you will learn how to place some markers, polylines and popups on a *Leaflet* map.
#
# The code below creates a plain map. The details of the parameters in `folium.Map` have been explained in notebook 1.

# %%
map = folium.Map(location=[52.159023564272175, 4.492176575878583],
tiles="Stamen Terrain",
width="100%",
height="100%",
zoom_start=10)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a073527c7bcc48609930af34671168de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a073527c7bcc48609930af34671168de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a073527c7bcc48609930af34671168de = L.map(
#                 &quot;map_a073527c7bcc48609930af34671168de&quot;,
#                 {
#                     center: [52.159023564272175, 4.492176575878583],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9bb223f6763507405f268830d37cf106 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a073527c7bcc48609930af34671168de);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## A Marker
#
# You can indicate a specific location on the map by added a `Marker`. As a parameter, you need to provide the coordinates of the location of this marker. More specifically, you need to specify the latitude and the longitude as a Python list, in square brackets.
#
# To actuyally place the `Marker` on the map, you need to add the method `add_to()`.

# %%
map = folium.Map(location=[52.15723602487217, 4.482775926589967],
tiles = 'OpenStreetMap' ,
     width="90%",
    height="90%",
    zoom_start=15)

folium.Marker([52.157201304859825, 4.485295005258649]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e7739d2d8cbabf7a076d49a060f3e25 {
#                     position: relative;
#                     width: 90.0%;
#                     height: 90.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e7739d2d8cbabf7a076d49a060f3e25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e7739d2d8cbabf7a076d49a060f3e25 = L.map(
#                 &quot;map_7e7739d2d8cbabf7a076d49a060f3e25&quot;,
#                 {
#                     center: [52.15723602487217, 4.482775926589967],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0db2cd6a82e59b604fa254b026afefb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#             var marker_9bfb5632fd34cd89afa1948cc4b17a6e = L.marker(
#                 [52.157201304859825, 4.485295005258649],
#                 {}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can also add a `popup` parameter to the `Marker`. When you do this, the text provided for the popup will become visible if it is clicked on.

# %%
folium.Marker([52.157201304859825, 4.485295005258649],
    popup = 'Academy Building in Leiden' ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e7739d2d8cbabf7a076d49a060f3e25 {
#                     position: relative;
#                     width: 90.0%;
#                     height: 90.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e7739d2d8cbabf7a076d49a060f3e25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e7739d2d8cbabf7a076d49a060f3e25 = L.map(
#                 &quot;map_7e7739d2d8cbabf7a076d49a060f3e25&quot;,
#                 {
#                     center: [52.15723602487217, 4.482775926589967],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0db2cd6a82e59b604fa254b026afefb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#             var marker_9bfb5632fd34cd89afa1948cc4b17a6e = L.marker(
#                 [52.157201304859825, 4.485295005258649],
#                 {}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#             var marker_c0805f909beadfb701b2b9093e4cc13e = L.marker(
#                 [52.157201304859825, 4.485295005258649],
#                 {}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#         var popup_b4f62c911f709518b19bff1ed1ae95be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d88f190ad5d0130e4343320368c0a2f7 = $(`&lt;div id=&quot;html_d88f190ad5d0130e4343320368c0a2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Academy Building in Leiden&lt;/div&gt;`)[0];
#                 popup_b4f62c911f709518b19bff1ed1ae95be.setContent(html_d88f190ad5d0130e4343320368c0a2f7);
#
#
#
#         marker_c0805f909beadfb701b2b9093e4cc13e.bindPopup(popup_b4f62c911f709518b19bff1ed1ae95be)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Alternatively, you can work with the `tooltip` parameter. The text that is given will then appear when users hover over the marker.

# %%
folium.Marker([52.15480614361388, 4.483881607791887],
    tooltip = 'Old Observatory' ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e7739d2d8cbabf7a076d49a060f3e25 {
#                     position: relative;
#                     width: 90.0%;
#                     height: 90.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e7739d2d8cbabf7a076d49a060f3e25&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e7739d2d8cbabf7a076d49a060f3e25 = L.map(
#                 &quot;map_7e7739d2d8cbabf7a076d49a060f3e25&quot;,
#                 {
#                     center: [52.15723602487217, 4.482775926589967],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0db2cd6a82e59b604fa254b026afefb4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#             var marker_9bfb5632fd34cd89afa1948cc4b17a6e = L.marker(
#                 [52.157201304859825, 4.485295005258649],
#                 {}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#             var marker_c0805f909beadfb701b2b9093e4cc13e = L.marker(
#                 [52.157201304859825, 4.485295005258649],
#                 {}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#         var popup_b4f62c911f709518b19bff1ed1ae95be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d88f190ad5d0130e4343320368c0a2f7 = $(`&lt;div id=&quot;html_d88f190ad5d0130e4343320368c0a2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Academy Building in Leiden&lt;/div&gt;`)[0];
#                 popup_b4f62c911f709518b19bff1ed1ae95be.setContent(html_d88f190ad5d0130e4343320368c0a2f7);
#
#
#
#         marker_c0805f909beadfb701b2b9093e4cc13e.bindPopup(popup_b4f62c911f709518b19bff1ed1ae95be)
#         ;
#
#
#
#
#             var marker_eb0e1b118e1fb183e77ebf6448efaeca = L.marker(
#                 [52.15480614361388, 4.483881607791887],
#                 {}
#             ).addTo(map_7e7739d2d8cbabf7a076d49a060f3e25);
#
#
#             marker_eb0e1b118e1fb183e77ebf6448efaeca.bindTooltip(
#                 `&lt;div&gt;
#                      Old Observatory
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This text given as value for the `tooltip` may also contain HTML code. You can use HTML code to create a hyperlink, for example.

# %%
popup_text = '<a href="https://www.universiteitleiden.nl/en/locations/academy-building" target="_blank">Academy Building in Leiden</a>'

map = folium.Map(location=[52.15723602487217, 4.482775926589967],
tiles = 'OpenStreetMap' ,
     width="90%",
    height="90%",
    zoom_start=15)


map = folium.Map(location=[52.15723602487217, 4.482775926589967],
tiles = 'OpenStreetMap' ,
     width="90%",
    height="90%",
    zoom_start=15)

folium.Marker([52.157201304859825, 4.485295005258649],
    popup = popup_text ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a06766439075039f73e899c9f39f1f9 {
#                     position: relative;
#                     width: 90.0%;
#                     height: 90.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a06766439075039f73e899c9f39f1f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a06766439075039f73e899c9f39f1f9 = L.map(
#                 &quot;map_7a06766439075039f73e899c9f39f1f9&quot;,
#                 {
#                     center: [52.15723602487217, 4.482775926589967],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d73127b3d46c546ea86efe053d975344 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a06766439075039f73e899c9f39f1f9);
#
#
#             var marker_4589f4903f006064ded2fe961e37fa0e = L.marker(
#                 [52.157201304859825, 4.485295005258649],
#                 {}
#             ).addTo(map_7a06766439075039f73e899c9f39f1f9);
#
#
#         var popup_6c606fe2de6758ca1281069d409328ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0870280ab65c731b179a4faae34440f = $(`&lt;div id=&quot;html_c0870280ab65c731b179a4faae34440f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.universiteitleiden.nl/en/locations/academy-building&quot; target=&quot;_blank&quot;&gt;Academy Building in Leiden&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_6c606fe2de6758ca1281069d409328ee.setContent(html_c0870280ab65c731b179a4faae34440f);
#
#
#
#         marker_4589f4903f006064ded2fe961e37fa0e.bindPopup(popup_6c606fe2de6758ca1281069d409328ee)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Exercise 2.1.

# %% [markdown]
# `folium` has a useful method named `LatLngPopup`. This method lets you find coordinates very easily. If you click on the map, you will see the coordinates.
#
# A similar method, named `ClickForLatLng`, also copies these coordinates to the clipboard.

# %%
map = folium.Map(location=[51.50111656588214, -0.1228658709481792],
tiles = 'OpenStreetMap' ,
    zoom_start=15)
map.add_child(folium.features.ClickForLatLng())
map.add_child(folium.LatLngPopup())
map.save('coordinates.html')

# %% [markdown]
# The code above creates a map named 'coordinates.html'. Using this interactive map, try to find the coordinates of two monuments or landmarks in the centre of London.
#
# Add `Markers` to the map below for the locations you have found. Add a popup with a description of these locations.

# %%
map = folium.Map(location=[51.50111656588214, -0.1228658709481792],
tiles = 'OpenStreetMap' ,
    zoom_start=13)

folium.Marker([0,0],
    popup = "" ).add_to(map)

folium.Marker([0,1],
    popup = "" ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ebc0e3ce95f6adf563d8957e273319ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ebc0e3ce95f6adf563d8957e273319ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ebc0e3ce95f6adf563d8957e273319ce = L.map(
#                 &quot;map_ebc0e3ce95f6adf563d8957e273319ce&quot;,
#                 {
#                     center: [51.50111656588214, -0.1228658709481792],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e39dcfe9087ea0a1f00ec702d6f55f1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ebc0e3ce95f6adf563d8957e273319ce);
#
#
#             var marker_843ff56b9b68cb40582ef4a9c5524cba = L.marker(
#                 [0.0, 0.0],
#                 {}
#             ).addTo(map_ebc0e3ce95f6adf563d8957e273319ce);
#
#
#         var popup_d006b0eedb1f9779afabcbca373d32f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7d58b1a9dbc5d09e9cc3331143e551b = $(`&lt;div id=&quot;html_d7d58b1a9dbc5d09e9cc3331143e551b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_d006b0eedb1f9779afabcbca373d32f8.setContent(html_d7d58b1a9dbc5d09e9cc3331143e551b);
#
#
#
#         marker_843ff56b9b68cb40582ef4a9c5524cba.bindPopup(popup_d006b0eedb1f9779afabcbca373d32f8)
#         ;
#
#
#
#
#             var marker_194b0d471f84e9d4ae9f775633b53477 = L.marker(
#                 [0.0, 1.0],
#                 {}
#             ).addTo(map_ebc0e3ce95f6adf563d8957e273319ce);
#
#
#         var popup_d274d125c6754d06202daed16c73dd26 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_df29fd83488dd8e87ff05d99b9b76e0d = $(`&lt;div id=&quot;html_df29fd83488dd8e87ff05d99b9b76e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_d274d125c6754d06202daed16c73dd26.setContent(html_df29fd83488dd8e87ff05d99b9b76e0d);
#
#
#
#         marker_194b0d471f84e9d4ae9f775633b53477.bindPopup(popup_d274d125c6754d06202daed16c73dd26)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Circle
#
# A location can also be indicated using a `Circle`.
#
# The appearance of such a circle can be manipulated using the following parameters.
#
# * `radius` changes the overall size of the circle.
# * `weight` determines the width of the border. The default width is 3.
# * `color` changes the colour of the border of the circle. To find colour codes, you can work with a [color picker tool](https://g.co/kgs/do8izv).
# * If you set `fill` to 'True', the interior of the circle will be coloured as well.
# * `fill_color` determines the colour of the body of the circle. It can be different from the colour of the border.
# * You can work with the `fill_opacity` parameter to make the circle transparent. With value 0, the circle will be fully transparent. If the circle has an opacity of 1, there is no transparency.
# * As is the case for the marker, you can also add a `popup`.

# %%
map = folium.Map(location=[51.51366683783708, -0.09821931016133895],tiles="Stamen Terrain",
width="%80",
height="%100",
zoom_start=14)

folium.Circle(
    location=[51.51366683783708, -0.09821931016133895],
    radius=120,
    color='#1827c9',
    fill=False ,
    fill_opacity = 0.5,
    fill_color = '#c72d22' ,
    weight = 3 ,
    popup = "St. Paul's Cathedral" ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76a2c5989077531d047d66a3193463ed {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76a2c5989077531d047d66a3193463ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76a2c5989077531d047d66a3193463ed = L.map(
#                 &quot;map_76a2c5989077531d047d66a3193463ed&quot;,
#                 {
#                     center: [51.51366683783708, -0.09821931016133895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36e19b53915c34873c560535e65d48e9 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_76a2c5989077531d047d66a3193463ed);
#
#
#             var circle_3ec18e2e2a116a66b105e5f7184a62f2 = L.circle(
#                 [51.51366683783708, -0.09821931016133895],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1827c9&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c72d22&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 120, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_76a2c5989077531d047d66a3193463ed);
#
#
#         var popup_b8462bf439c559ab2c3d481c5a7a0a7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b2cfd622dabf7498fc88a0cb26583ef1 = $(`&lt;div id=&quot;html_b2cfd622dabf7498fc88a0cb26583ef1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St. Paul&#x27;s Cathedral&lt;/div&gt;`)[0];
#                 popup_b8462bf439c559ab2c3d481c5a7a0a7a.setContent(html_b2cfd622dabf7498fc88a0cb26583ef1);
#
#
#
#         circle_3ec18e2e2a116a66b105e5f7184a62f2.bindPopup(popup_b8462bf439c559ab2c3d481c5a7a0a7a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Circle Marker
#
# The size of a `Circle` is flexible. It is adjusted when user of the map zooms in or out. A `CircleMarker`, by contrast, will always have the radius that was specified originally.
#
# The appearance of the `Circle` can be used with the exact same parameters.

# %%
map = folium.Map(location=[51.51366683783708, -0.09821931016133895],tiles="Stamen Terrain",
width="%80",
height="%100",
zoom_start=14)

folium.CircleMarker(
    location=[51.51366683783708, -0.09821931016133895],
    radius=50,
    color='#3f7509',
    fill=False ,
    fill_color = '#3b5c19' ,
    fill_opacity = 0.4 , 
    weight = 3 ,
    popup = "St. Paul's Cathedral" ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c64b0ea6b01b90668bceff4d4213d68 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c64b0ea6b01b90668bceff4d4213d68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c64b0ea6b01b90668bceff4d4213d68 = L.map(
#                 &quot;map_6c64b0ea6b01b90668bceff4d4213d68&quot;,
#                 {
#                     center: [51.51366683783708, -0.09821931016133895],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d2744d54929cb4a92d5017bccb97409 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c64b0ea6b01b90668bceff4d4213d68);
#
#
#             var circle_marker_f6cee5389bbd748ded2253314bda1efa = L.circleMarker(
#                 [51.51366683783708, -0.09821931016133895],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3f7509&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3b5c19&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6c64b0ea6b01b90668bceff4d4213d68);
#
#
#         var popup_cad1b2ec3f4c190634713ee0c2c32e61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdad8ccd0bc90fc840382784fca08647 = $(`&lt;div id=&quot;html_fdad8ccd0bc90fc840382784fca08647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St. Paul&#x27;s Cathedral&lt;/div&gt;`)[0];
#                 popup_cad1b2ec3f4c190634713ee0c2c32e61.setContent(html_fdad8ccd0bc90fc840382784fca08647);
#
#
#
#         circle_marker_f6cee5389bbd748ded2253314bda1efa.bindPopup(popup_cad1b2ec3f4c190634713ee0c2c32e61)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Plotting locations described in a CSV file
#
# As was explained above, you can add markers and circles to indicate places on a map.
#
# If you want to plot a large number of locations, it can be useful to make a separate file containing all the locations. Using code, you can then add `Markers` to the map for all the locations in this file. Comma Separated Value file (CSV) is a very common file format for such data.
#
# This CSV file describes locations of museums in Paris. As you can see, the file describes the latitute and longitude. The data also includes a brief descriptino of the locations.
#
# ```
# latitude,longitude,description
# 48.86056457456627,2.3375939272302153,Louvre Museum
# 48.86003165994765,2.32658077703463,Musée d'Orsay
# 48.855139873885015,2.3159270427078726,Musée Rodin
# 48.8608257894529,2.3527472909202767,Centre Pompidou
# ```
#
#
# In a Python programme, you can read CSV files using a library named `pandas`. This package has a methods named `read_csv()` to read the contents of a CSV file. This method creates a dataframe. This is a data sctructure which consists of rows and of columns. The method named `iterrows()` enable you iterate across all the rows in the dataframe.

# %%
import pandas as pd
museums = pd.read_csv('paris_museums.csv')
for i,row in museums.iterrows():
    print(row['description'])
    print(f"Latitude: {row['latitude']}, Longitude: {row['longitude']}\n")
# Out:
# Louvre Museum
# Latitude: 48.86056457456627, Longitude: 2.3375939272302158
#
# Musée d'Orsay
# Latitude: 48.86003165994765, Longitude: 2.32658077703463
#
# Musée Rodin
# Latitude: 48.855139873885015, Longitude: 2.3159270427078726
#
# Centre Pompidou
# Latitude: 48.8608257894529, Longitude: 2.3527472909202767

# %% [markdown]
# Next, we can write code to add all the locations described in the CSV file as markers.

# %%
map = folium.Map(location=[48.86212799332407, 2.3234206439367],
                zoom_start = 13 )


df = pd.read_csv('paris_museums.csv')

for i,row in df.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    museum_name = row['description']
    
    folium.Marker([latitude, longitude],
    tooltip = museum_name ).add_to(map)

    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e8ab53c030236e655c24aec60819bd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e8ab53c030236e655c24aec60819bd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e8ab53c030236e655c24aec60819bd0 = L.map(
#                 &quot;map_9e8ab53c030236e655c24aec60819bd0&quot;,
#                 {
#                     center: [48.86212799332407, 2.3234206439367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e893dca8a3482ac243358c4e14e91578 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e8ab53c030236e655c24aec60819bd0);
#
#
#             var marker_1bbd8ee240eff79d308c03ab6ae1e75e = L.marker(
#                 [48.86056457456627, 2.3375939272302158],
#                 {}
#             ).addTo(map_9e8ab53c030236e655c24aec60819bd0);
#
#
#             marker_1bbd8ee240eff79d308c03ab6ae1e75e.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre Museum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d92bf2a96106280b8f04560991bb3638 = L.marker(
#                 [48.86003165994765, 2.32658077703463],
#                 {}
#             ).addTo(map_9e8ab53c030236e655c24aec60819bd0);
#
#
#             marker_d92bf2a96106280b8f04560991bb3638.bindTooltip(
#                 `&lt;div&gt;
#                      Musée d&#x27;Orsay
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0dd69faeef4be24b64298dced0c59eb = L.marker(
#                 [48.855139873885015, 2.3159270427078726],
#                 {}
#             ).addTo(map_9e8ab53c030236e655c24aec60819bd0);
#
#
#             marker_b0dd69faeef4be24b64298dced0c59eb.bindTooltip(
#                 `&lt;div&gt;
#                      Musée Rodin
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7df3d5e0e6990de0125981ca4c936363 = L.marker(
#                 [48.8608257894529, 2.3527472909202767],
#                 {}
#             ).addTo(map_9e8ab53c030236e655c24aec60819bd0);
#
#
#             marker_7df3d5e0e6990de0125981ca4c936363.bindTooltip(
#                 `&lt;div&gt;
#                      Centre Pompidou
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Exercise
#
# Create a *Google Spreadsheet* with the following columns:
#
# * latitude
# * longitude
# * description
#
# If yoyu want, you can also copy a [template](https://docs.google.com/spreadsheets/d/15pIw7cA5MzR_eAMPOJ96XFi4L4H9CmVW6VPsY0O-q-M/edit#gid=0).
#
# Next, use this spreadsheet to collect the coordinates of a number of monuments or historical landmarks in the city of Amsterdam.
#
# Once you are done, export the spreadsheet as a CSV file, and save the export as 'map.csv'. Next, plot these locations on a map using the code below.

# %%
map = folium.Map(location=[52.37342908811543, 4.893317395003621],
                 tiles = 'OpenStreetMap' ,
                zoom_start = 14 )

df = pd.read_csv('map.csv')

for i,row in df.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    museum_name = row['description']
    
    folium.Marker([latitude, longitude],
    popup = museum_name ).add_to(map)

    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fd41da557b9d8b43afd4a293167b39c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fd41da557b9d8b43afd4a293167b39c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fd41da557b9d8b43afd4a293167b39c = L.map(
#                 &quot;map_7fd41da557b9d8b43afd4a293167b39c&quot;,
#                 {
#                     center: [52.37342908811543, 4.893317395003621],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_940d03a7831c44463ae3dddc209284ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7fd41da557b9d8b43afd4a293167b39c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Custom Icons

# %% [markdown]
# By default, *Leaflet* uses a blue droplet-shaped icon for the `Marker`. You can change the icon that is used on *Leaflet* maps, however.
#
# On the droplet, you can use icons from the [font awesome](https://fontawesome.com/v4/icons/) webpage. Each icon on this website is identified using a name beginning with 'fa-'.
#
# Examples include the following:
#
# * fa-map-pin
# * fa-car
# * fa-map
# * fa-street-view
# * fa-location-arrow
# * fa-map-o
#
# Some of the icons that have been added since version 4.7 of *font awasome* may not be avaiable yet.
#
# The colour of the droplet can also be changes. You can work with the following pre-defines colours:
#
# 'beige', 'darkgreen', 'cadetblue', 'pink', 'gray', 'white', 'darkpurple', 'green', 'black', 'lightgray', 'darkred', 'blue', 'red', 'orange', 'lightgreen', 'darkblue', 'purple', 'lightred', 'lightblue'

# %%
fa_icon = 'fa-map'
custom_color = 'darkred'

custom_icon = folium.Icon(icon= fa_icon , color= custom_color , prefix='fa' )


map = folium.Map(location=[52.15723602487217, 4.482775926589967],
    tiles="Stamen terrain",
     width="90%",
    height="90%",
    zoom_start=10)

folium.Marker([52.15723602487217, 4.482775926589967] , icon = custom_icon  ).add_to(map)

map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nf/35gdwksd0fx8kzbsljz4dz6hnrcnxq/T/ipykernel_14067/1517669489.py in <module>
#       2 custom_color = 'darkred'
#       3
# ----> 4 custom_icon = folium.Icon(icon= fa_icon , color= custom_color , prefix='fa' )
#       5
#       6
#
# NameError: name 'folium' is not defined

# %% [markdown]
# You can also change the shape of the marker. To do this. you need to supply the URL of an icon image. A large number of such icons can be found on the [icons8](https://icons8.com/icons/set/map) website. On this site, you need to right-clich and select "Copy URL".
#
# The list below contains some URLs you can work with.
#
# * https://cdn-icons-png.flaticon.com/128/4300/4300279.png
# * http://leafletjs.com/examples/custom-icons/leaf-green.png
# * https://cdn-icons-png.flaticon.com/128/4300/4300279.png
# * https://img.icons8.com/?size=2x&id=54qCxYO5RODV&format=png
# * https://img.icons8.com/?size=2x&id=86820&format=png

# %%
icon_url = 'https://cdn-icons-png.flaticon.com/128/4300/4300279.png'

custom_icon = folium.features.CustomIcon(
    icon_url, 
    icon_size=[30,] )

map = folium.Map(location=[52.15723602487217, 4.482775926589967],
    tiles="CartoDB positron",
     width="90%",
    height="90%",
    zoom_start=10)

folium.Marker([52.15723602487217, 4.482775926589967] , 
              icon = custom_icon ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eff97c62b8cd61448d8205d8b1526a4c {
#                     position: relative;
#                     width: 90.0%;
#                     height: 90.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eff97c62b8cd61448d8205d8b1526a4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eff97c62b8cd61448d8205d8b1526a4c = L.map(
#                 &quot;map_eff97c62b8cd61448d8205d8b1526a4c&quot;,
#                 {
#                     center: [52.15723602487217, 4.482775926589967],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72f9b94ef30445dfcf381af7109a3fb3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_eff97c62b8cd61448d8205d8b1526a4c);
#
#
#             var marker_f6df97ae65b54c6fc3a350979938a5ce = L.marker(
#                 [52.15723602487217, 4.482775926589967],
#                 {}
#             ).addTo(map_eff97c62b8cd61448d8205d8b1526a4c);
#
#
#         var custom_icon_793cbc8f4e32c1ddc2ea970b34867a31 = L.icon({&quot;iconSize&quot;: [30], &quot;iconUrl&quot;: &quot;https://cdn-icons-png.flaticon.com/128/4300/4300279.png&quot;});
#         marker_f6df97ae65b54c6fc3a350979938a5ce.setIcon(custom_icon_793cbc8f4e32c1ddc2ea970b34867a31);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
